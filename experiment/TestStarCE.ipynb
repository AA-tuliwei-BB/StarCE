# %% [markdown]
# # Test StarCE

# %% [markdown]
# ## Build

# %% [markdown]
# ### Init

# %%
import sys
import os
from pathlib import Path

# Add experiment directory to path
sys.path.append(os.path.abspath('.'))

from ExperimentRunner import StarCETestRunner

# Project root directory
project_root = os.path.abspath('..')

# Output to experiment/checkpoint/StarCE directory
checkpoint_dir = os.path.abspath('./checkpoint/StarCE')
os.makedirs(checkpoint_dir, exist_ok=True)

# Create runner
runner = StarCETestRunner(project_root)

def build_starce_benchmark(db_name):
    """
    Build StarCE statistics object

    Args:
        db_name: Database name ('STATS', 'IMDB', 'IMDB_LIGHT', 'IMDB_LIGHT_RANGES', 'JobJoin', 'StatsJoin')

    Returns:
        tuple: (build time, statistics raw data size)
    """
    if db_name == 'STATS':
        config = runner.get_stats_db_config()
    elif db_name == 'IMDB':
        config = runner.get_imdb_db_config()
    elif db_name == 'IMDB_LIGHT':
        config = runner.get_imdb_light_db_config()
    elif db_name == 'IMDB_LIGHT_RANGES':
        config = runner.get_imdb_light_ranges_db_config()
    elif db_name == 'JobJoin':
        config = runner.get_jobjoin_config()
    elif db_name == 'StatsJoin':
        config = runner.get_statsjoin_config()
    else:
        raise ValueError(f"Unsupported database name: {db_name}")

    config.RefreshStatistics = 1
    # JobJoin and StatsJoin contain large multi-table joins;
    # build only needs statistics collection, skip query execution.
    if db_name in ('JobJoin', 'StatsJoin'):
        config.SQL_PATH = 'dummy_query.sql'
    time, size = runner.inner_test_build_time(config, db_name, num_runs=1)
    print(f"\nBuild results:")
    print(f"  Build time: {time:.2f} seconds")
    print(f"  Statistics size (data_only): {size} bytes ({size/1024/1024:.2f} MB)")
    return time, size

print("Configuration complete, use build_starce_benchmark() to build each database")

# %% [markdown]
# ### Stats Benchmark

# %%
stats_build_time, stats_stats_size = build_starce_benchmark('STATS')
# Out:
# --- Testing build time - StarCE - (STATS) ---
# [2026-06-27 21:06:57] Started testing build time - StarCE - (STATS), Run 1/1
# [2026-06-27 21:06:57] Config file saved to: /home/user/project/starCE/experiment/running_space/config.json
# [2026-06-27 21:06:57] Run 1/1...
# [2026-06-27 21:06:57] starce ran successfully，elapsed: 0.13 seconds
# [2026-06-27 21:06:57] stdout:
# eset size: 6
# eset size: 6
# eset size: 6
# Build time test results (STATS):
#   Successful runs: 1/1
#   Average build time: 0.13 seconds
#   Fastest: 0.13 seconds
#   Slowest: 0.13 seconds
#   Statistics size (data_only): 128161 bytes (0.12 MB)
#
# Build results:
#   Build time: 0.13 seconds
#   Statistics size (data_only): 128161 bytes (0.12 MB)

# %% [markdown]
# ### JOBM Benchmark

# %%
jobm_build_time, jobm_stats_size = build_starce_benchmark('IMDB')
# Out:
# --- Testing build time - StarCE - (IMDB) ---
# [2026-06-27 21:06:57] Started testing build time - StarCE - (IMDB), Run 1/1
# [2026-06-27 21:06:57] Config file saved to: /home/user/project/starCE/experiment/running_space/config.json
# [2026-06-27 21:06:57] Run 1/1...
# [2026-06-27 21:07:11] starce ran successfully，elapsed: 13.50 seconds
# [2026-06-27 21:07:11] stdout:
# eset size: 2
# eset size: 9
# eset size: 9
# eset size: 4
# eset size: 2
# eset size: 2
# eset size: 4
# eset size: 2
# eset size: 2
# eset size: 2
# eset size: 2
# eset size: 3
# eset size: 2
# eset size: 2
# Build time test results (IMDB):
#   Successful runs: 1/1
#   Average build time: 13.50 seconds
#   Fastest: 13.50 seconds
#   Slowest: 13.50 seconds
#   Statistics size (data_only): 1414344 bytes (1.35 MB)
#
# Build results:
#   Build time: 13.50 seconds
#   Statistics size (data_only): 1414344 bytes (1.35 MB)

# %% [markdown]
# ### JOBLight Benchmark

# %%
joblight_build_time, joblight_stats_size = build_starce_benchmark('IMDB_LIGHT')
# Out:
# --- Testing build time - StarCE - (IMDB_LIGHT) ---
# [2026-06-27 21:07:11] Started testing build time - StarCE - (IMDB_LIGHT), Run 1/1
# [2026-06-27 21:07:11] Config file saved to: /home/user/project/starCE/experiment/running_space/config.json
# [2026-06-27 21:07:11] Run 1/1...
# [2026-06-27 21:07:13] starce ran successfully，elapsed: 2.88 seconds
# [2026-06-27 21:07:13] stdout:
# eset size: 6
# eset size: 6
# eset size: 2
# Build time test results (IMDB_LIGHT):
#   Successful runs: 1/1
#   Average build time: 2.88 seconds
#   Fastest: 2.88 seconds
#   Slowest: 2.88 seconds
#   Statistics size (data_only): 94558 bytes (0.09 MB)
#
# Build results:
#   Build time: 2.88 seconds
#   Statistics size (data_only): 94558 bytes (0.09 MB)

# %% [markdown]
# ### JOBLightRanges Benchmark

# %%
joblr_build_time, joblr_stats_size = build_starce_benchmark('IMDB_LIGHT_RANGES')
# Out:
# --- Testing build time - StarCE - (IMDB_LIGHT_RANGES) ---
# [2026-06-27 21:07:13] Started testing build time - StarCE - (IMDB_LIGHT_RANGES), Run 1/1
# [2026-06-27 21:07:13] Config file saved to: /home/user/project/starCE/experiment/running_space/config.json
# [2026-06-27 21:07:13] Run 1/1...
# [2026-06-27 21:07:16] starce ran successfully，elapsed: 3.04 seconds
# [2026-06-27 21:07:16] stdout:
# eset size: 6
# eset size: 6
# eset size: 2
# Build time test results (IMDB_LIGHT_RANGES):
#   Successful runs: 1/1
#   Average build time: 3.04 seconds
#   Fastest: 3.04 seconds
#   Slowest: 3.04 seconds
#   Statistics size (data_only): 94558 bytes (0.09 MB)
#
# Build results:
#   Build time: 3.04 seconds
#   Statistics size (data_only): 94558 bytes (0.09 MB)

# %%
jobjoin_build_time, jobjoin_stats_size = build_starce_benchmark('JobJoin')
# Out:
# --- Testing build time - StarCE - (JobJoin) ---
# [2026-06-27 21:07:16] Started testing build time - StarCE - (JobJoin), Run 1/1
# [2026-06-27 21:07:16] Config file saved to: /home/user/project/starCE/experiment/running_space/config.json
# [2026-06-27 21:07:16] Run 1/1...
# [2026-06-27 21:07:30] starce ran successfully，elapsed: 13.14 seconds
# [2026-06-27 21:07:30] stdout:
# eset size: 2
# eset size: 9
# eset size: 9
# eset size: 4
# eset size: 2
# eset size: 2
# eset size: 4
# eset size: 2
# eset size: 2
# eset size: 2
# eset size: 2
# eset size: 3
# eset size: 2
# eset size: 2
# Build time test results (JobJoin):
#   Successful runs: 1/1
#   Average build time: 13.14 seconds
#   Fastest: 13.14 seconds
#   Slowest: 13.14 seconds
#   Statistics size (data_only): 1414344 bytes (1.35 MB)
#
# Build results:
#   Build time: 13.14 seconds
#   Statistics size (data_only): 1414344 bytes (1.35 MB)

# %%
statsjoin_build_time, statsjoin_stats_size = build_starce_benchmark('StatsJoin')

# %% [markdown]
# ### JobJoin Benchmark

# %% [markdown]
# ### StatsJoin Benchmark

# %% [markdown]
# ## Evaluate

# %% [markdown]
# ### Init

# %%
import time
import os

def evaluate_starce_benchmark(benchmark):
    """
    Evaluate StarCE statistics object cardinality estimation on SQL queries

    Args:
        benchmark: benchmark name ('Stats', 'JOBM')

    Returns:
        dict: Dictionary containing evaluation results, including:
            - total_time: Total evaluation time (seconds)
            - output_file: Result output file path
    """
    return runner.get_est_cards(benchmark)

print("Evaluation function defined, use evaluate_starce_benchmark() to evaluate each benchmark")
# Out:
# Evaluation function defined, use evaluate_starce_benchmark() function to evaluate each benchmark

# %% [markdown]
# ### Stats Benchmark

# %%
# Execute evaluation
stats_results = evaluate_starce_benchmark(benchmark='Stats')
stats_results
# Out:
# [2026-06-27 21:07:30] Copied queries file to /home/user/project/starCE/experiment/running_space/explain.sql and added EXPLAIN
# [2026-06-27 21:07:30] Config file saved to: /home/user/project/starCE/experiment/running_space/config.json
# [2026-06-27 21:07:30] starce ran successfully，elapsed: 0.20 seconds
# {'benchmark': 'Stats',
#  'total_time': 0.2075047492980957,
#  'output_file': '/home/user/project/starCE/experiment/checkpoint/StarCE/card_stats.txt'}

# %% [markdown]
# ### JOBM Benchmark

# %%
# Execute evaluation
jobm_results = evaluate_starce_benchmark(benchmark='JOBM')
jobm_results
# Out:
# [2026-06-27 21:07:30] Copied queries file to /home/user/project/starCE/experiment/running_space/explain.sql and added EXPLAIN
# [2026-06-27 21:07:30] Config file saved to: /home/user/project/starCE/experiment/running_space/config.json
# [2026-06-27 21:07:30] starce ran successfully，elapsed: 0.58 seconds
# {'benchmark': 'JOBM',
#  'total_time': 0.5860044956207275,
#  'output_file': '/home/user/project/starCE/experiment/checkpoint/StarCE/card_jobm.txt'}

# %% [markdown]
# ### JOBLight Benchmark

# %%
# Execute evaluation
joblight_results = evaluate_starce_benchmark(benchmark='JOBLight')
joblight_results
# Out:
# [2026-06-27 21:07:30] Copied queries file to /home/user/project/starCE/experiment/running_space/explain.sql and added EXPLAIN
# [2026-06-27 21:07:30] Config file saved to: /home/user/project/starCE/experiment/running_space/config.json
# [2026-06-27 21:07:31] starce ran successfully，elapsed: 0.08 seconds
# {'benchmark': 'JOBLight',
#  'total_time': 0.08220124244689941,
#  'output_file': '/home/user/project/starCE/experiment/checkpoint/StarCE/card_joblight.txt'}

# %% [markdown]
# ### JOBLightRanges Benchmark

# %%
# Execute evaluation
joblr_results = evaluate_starce_benchmark(benchmark='JOBLightRanges')
joblr_results
# Out:
# [2026-06-27 21:07:31] Copied queries file to /home/user/project/starCE/experiment/running_space/explain.sql and added EXPLAIN
# [2026-06-27 21:07:31] Config file saved to: /home/user/project/starCE/experiment/running_space/config.json
# [2026-06-27 21:07:31] starce ran successfully，elapsed: 0.89 seconds
# {'benchmark': 'JOBLightRanges',
#  'total_time': 0.9137756824493408,
#  'output_file': '/home/user/project/starCE/experiment/checkpoint/StarCE/card_joblr.txt'}

# %% [markdown]
# ### JobJoin Benchmark

# %%
# Execute evaluation
jobjoin_results = evaluate_starce_benchmark(benchmark='JobJoin')
jobjoin_results
# Out:
# [2026-06-27 21:07:31] Copied queries file to /home/user/project/starCE/experiment/running_space/explain.sql and added EXPLAIN
# [2026-06-27 21:07:31] Config file saved to: /home/user/project/starCE/experiment/running_space/config.json
# {'benchmark': 'JobJoin',
#  'total_time': 0.6362016201019287,
#  'output_file': '/home/user/project/starCE/experiment/checkpoint/StarCE/card_jobjoin.txt'}

# %% [markdown]
# ### StatsJoin Benchmark

# %%
# Execute evaluation
statsjoin_results = evaluate_starce_benchmark(benchmark='StatsJoin')
statsjoin_results

# %%
# Save build/statistics/evaluation time to CSV
import csv

benchmarks = [
    {"name": "STATS", "build_db": "STATS", "eval_benchmark": "Stats"},
    {"name": "JOBM", "build_db": "IMDB", "eval_benchmark": "JOBM"},
    {"name": "JOBLight", "build_db": "IMDB_LIGHT", "eval_benchmark": "JOBLight"},
    {"name": "JOBLightRanges", "build_db": "IMDB_LIGHT_RANGES", "eval_benchmark": "JOBLightRanges"},
    {"name": "JobJoin", "build_db": "JobJoin", "eval_benchmark": "JobJoin"},
    {"name": "StatsJoin", "build_db": "StatsJoin", "eval_benchmark": "StatsJoin"},
]

rows = []
for item in benchmarks:
    name = item["name"]

    if name == "STATS":
        build_time, stats_size = stats_build_time, stats_stats_size
        eval_result = stats_results
    elif name == "JOBM":
        build_time, stats_size = jobm_build_time, jobm_stats_size
        eval_result = jobm_results
    elif name == "JOBLight":
        build_time, stats_size = joblight_build_time, joblight_stats_size
        eval_result = joblight_results
    elif name == "JOBLightRanges":
        build_time, stats_size = joblr_build_time, joblr_stats_size
        eval_result = joblr_results
    elif name == "JobJoin":
        build_time, stats_size = jobjoin_build_time, jobjoin_stats_size
        eval_result = jobjoin_results
    elif name == "StatsJoin":
        build_time, stats_size = statsjoin_build_time, statsjoin_stats_size
        eval_result = statsjoin_results

    rows.append({
        "benchmark": name,
        "build_time_sec": build_time,
        "statistics_size_bytes": stats_size,
        "eval_time_sec": eval_result.get("total_time"),
    })

csv_path = os.path.join(checkpoint_dir, "benchmark_times.csv")
with open(csv_path, "w", newline="") as f:
    writer = csv.DictWriter(
        f,
        fieldnames=["benchmark", "build_time_sec", "statistics_size_bytes", "eval_time_sec"],
    )
    writer.writeheader()
    writer.writerows(rows)

print(f"Written to: {csv_path}")
